# %% [markdown]
# We will plot sigmoid (logistic) function:
#
# \begin{align}
# \sigma(x)=\frac{1}{1+e^{-x}}
# \end{align}

# %%
import numpy as np
from math import exp
import matplotlib.pyplot as plt
# %matplotlib notebook

def sigmoid(x):
    a = []
    for var in x:
        a.append(1/(1+exp(-var)))
    return a

def sigmoid_print(x):
    for var in x:
        temp = (1/(1+exp(var)))
        print("Logistic function at x = %d equals %f" % (var, temp))
        
plt.text(-9,0.8,r'$\sigma(x)=\frac{1}{1+\exp(-x)}$',fontsize=25)
    
# plot function
x = np.arange(-10., 10., 0.2)
sig = sigmoid(x)
plt.plot(x,sig)
plt.show()

# print values
x = np.arange(-5., 6., 1.)
sigmoid_print(x)
# Out:
# <img src="data:image/png;base64,...">
# Logistic function at x = -5 equals 0.993307
# Logistic function at x = -4 equals 0.982014
# Logistic function at x = -3 equals 0.952574
# Logistic function at x = -2 equals 0.880797
# Logistic function at x = -1 equals 0.731059
# Logistic function at x = 0 equals 0.500000
# Logistic function at x = 1 equals 0.268941
# Logistic function at x = 2 equals 0.119203
# Logistic function at x = 3 equals 0.047426
# Logistic function at x = 4 equals 0.017986
# Logistic function at x = 5 equals 0.006693

# %% [markdown]
# Math expressions on plots:
#
# http://matplotlib.org/users/mathtext.html
#
# Math expressions on markdown cells:
#
# http://jupyter-notebook.readthedocs.io/en/latest/examples/Notebook/Typesetting%20Equations.html
